# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbhai69/ITEC325_General_Repo/blob/main/ITEC325ExploratoryDataMining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## White Wine Dataset Exploratory Data Analysis and Predictive Linear Regression Model Building
# We start with basic statistical calculations, visualization, checking for correlation, chi-squared tests to identify the top five key predictors of wine quality.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


url = 'https://raw.githubusercontent.com/bobbhai69/ITEC325_General_Repo/refs/heads/main/white-wines-5.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8      6.0
# 1      9.5      6.0
# 2     10.1      6.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   float64
# dtypes: float64(12)
# memory usage: 459.3 KB

# %%
df.corr(method = 'pearson').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c2e19_row0_col0, #T_c2e19_row1_col1, #T_c2e19_row2_col2, #T_c2e19_row3_col3, #T_c2e19_row4_col4, #T_c2e19_row5_col5, #T_c2e19_row6_col6, #T_c2e19_row7_col7, #T_c2e19_row8_col8, #T_c2e19_row9_col9, #T_c2e19_row10_col10, #T_c2e19_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c2e19_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c2e19_row0_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_c2e19_row0_col3, #T_c2e19_row0_col6, #T_c2e19_row1_col6, #T_c2e19_row4_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_c2e19_row0_col4, #T_c2e19_row1_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_c2e19_row0_col5, #T_c2e19_row3_col8, #T_c2e19_row3_col11 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_c2e19_row0_col7, #T_c2e19_row3_col6, #T_c2e19_row6_col3 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# ...

# %%
# Calculating the standard deviation, min, max, mode, of the dataset
descriptive_stats = df.describe()  # Get descriptive statistics

# Calculate and add mode to the descriptive stats
for col in df.columns:
    mode_value = df[col].mode()[0]  # Get the first mode value for the column
    descriptive_stats.loc['mode', col] = mode_value  # Add mode to descriptive_stats

descriptive_stats  # Display all statistics, including mode
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
# mode        6.800000          0.280000     0.300000        1.200000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# ...

# %%
# We need to scale the data, we can do using min-max scalar, z-score scaling
from sklearn.preprocessing import MinMaxScaler, StandardScaler


scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)
df_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.307692          0.186275     0.216867        0.308282   0.106825
# 1       0.240385          0.215686     0.204819        0.015337   0.118694
# 2       0.413462          0.196078     0.240964        0.096626   0.121662
# 3       0.326923          0.147059     0.192771        0.121166   0.145401
# 4       0.326923          0.147059     0.192771        0.121166   0.145401
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.149826              0.373550  0.267785  0.254545   0.267442
# 1             0.041812              0.285383  0.132832  0.527273   0.313953
# 2             0.097561              0.204176  0.154039  0.490909   0.255814
# 3             0.156794              0.410673  0.163678  0.427273   0.209302
# 4             0.156794              0.410673  0.163678  0.427273   0.209302
#
#     alcohol  quality
# 0  0.129032      0.5
# ...

# %%
standardized_scaler = StandardScaler()
df_standard = standardized_scaler.fit_transform(df)
df_standard = pd.DataFrame(df_standard, columns=df.columns)
df_standard.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.172097         -0.081770     0.213280        2.821349  -0.035355
# 1      -0.657501          0.215896     0.048001       -0.944765   0.147747
# 2       1.475751          0.017452     0.543838        0.100282   0.193523
# 3       0.409125         -0.478657    -0.117278        0.415768   0.559727
# 4       0.409125         -0.478657    -0.117278        0.415768   0.559727
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.569932              0.744565  2.331512 -1.246921  -0.349184
# 1            -1.253019             -0.149685 -0.009154  0.740029   0.001342
# 2            -0.312141             -0.973336  0.358665  0.475102  -0.436816
# 3             0.687541              1.121091  0.525855  0.011480  -0.787342
# 4             0.687541              1.121091  0.525855  0.011480  -0.787342
#
#     alcohol  quality
# 0 -1.393152  0.13787
# ...

# %%
# Correlational matrix using the scaled data with coolwarm cmap
corr_matrix = df_scaled.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ca06e_row0_col0, #T_ca06e_row1_col1, #T_ca06e_row2_col2, #T_ca06e_row3_col3, #T_ca06e_row4_col4, #T_ca06e_row5_col5, #T_ca06e_row6_col6, #T_ca06e_row7_col7, #T_ca06e_row8_col8, #T_ca06e_row9_col9, #T_ca06e_row10_col10, #T_ca06e_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ca06e_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ca06e_row0_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_ca06e_row0_col3, #T_ca06e_row0_col6, #T_ca06e_row1_col6, #T_ca06e_row4_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_ca06e_row0_col4, #T_ca06e_row1_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ca06e_row0_col5, #T_ca06e_row3_col8, #T_ca06e_row3_col11 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ca06e_row0_col7, #T_ca06e_row3_col6, #T_ca06e_row6_col3 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# ...

# %%
import statsmodels.api as sm

# Define predictors and target
selected_attr = ['volatile acidity', 'chlorides', 'alcohol', 'density', 'total sulfur dioxide']
X = df_scaled[selected_attr]
y = df_scaled['quality']

# Add constant for intercept
X_sm = sm.add_constant(X)

# Fit OLS model on the full dataset
model = sm.OLS(y, X_sm).fit()
summary_table = model.summary2().tables[1]

# Standardize predictors and compute standardized coefficients
X_std = (X - X.mean()) / X.std()
X_std_sm = sm.add_constant(X_std)
model_std = sm.OLS(y, X_std_sm).fit()
standardized_coeffs = model_std.params.drop('const')

# Add standardized coefficients to summary
summary_table = summary_table.loc[selected_attr]
summary_table['Std. Coeffs'] = standardized_coeffs.values

# Calculate tolerance = 1- R^2 of each predictor regressed on the others
tolerance = {}
for attr in selected_attr:
  other_attr = [a for a in selected_attr if a != attr]
  lr = LinearRegression().fit(X_std[other_attr], X_std[attr])
  r2 = r2_score(X_std[attr], lr.predict(X_std[other_attr]))
  tolerance[attr] = 1-r2


# Add tolerance values
summary_table['Tolerance'] = [tolerance.get(attr, np.nan) for var in summary_table.index]

# Round for readability
summary_table = summary_table.round(4)

# Display the summary table
summary_table
# Out:
#                        Coef.  Std.Err.        t   P>|t|  [0.025  0.975]  \
# volatile acidity     -0.3519    0.0189 -18.6187  0.0000 -0.3889 -0.3148
# chlorides            -0.0770    0.0305  -2.5246  0.0116 -0.1367 -0.0172
# alcohol               0.4044    0.0155  26.0645  0.0000  0.3740  0.4349
# density               0.2875    0.0539   5.3340  0.0000  0.1818  0.3931
# total sulfur dioxide  0.0564    0.0221   2.5545  0.0107  0.0131  0.0996
#
#                       Std. Coeffs  Tolerance
# volatile acidity          -0.0348     0.7071
# chlorides                 -0.0050     0.7071
# alcohol                    0.0803     0.7071
# density                    0.0166     0.7071
# total sulfur dioxide       0.0056     0.7071
